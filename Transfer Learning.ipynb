# %%
import tensorflow as tf
from tensorflow.keras.layers import Input, Lambda, Dense, Flatten
from tensorflow.keras.models import Model
from tensorflow.keras.applications.vgg16 import VGG16
from tensorflow.keras.applications.vgg16 import preprocess_input
from tensorflow.keras.preprocessing import image
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Sequential
import numpy as np
from glob import glob
import matplotlib.pyplot as plt
# Out:
# C:\Users\rasoo\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:523: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\rasoo\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:524: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\rasoo\Anaconda3\lib\site-packages\tensorflow\python\framework\dtypes.py:525: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
IMAGE_SIZE = [224, 224]
vgg = VGG16(input_shape=(224,224,3), weights='imagenet', include_top=False)

# %%
vgg.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_2 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# ...

# %%
#when Include_top = True
#last_layer = vgg.get_layer('fc2').output

# %%
# don't train existing weights
for layer in vgg.layers:
  layer.trainable = False

# %%
#here you can check Non-trainble parameters
vgg.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_2 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# ...

# %%
x = Flatten()(vgg.output)

# %%
#x = Dense(128,activation='relu',name='fc1')(x)
x= Dense(4, activation='softmax')(x)

# %%
model = Model(inputs=(vgg.input), outputs=x)

# %%
model.summary()
# Out:
# Model: "model_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_6 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# ...

# %%
model.compile(
  loss='categorical_crossentropy',
  optimizer='adam',
  metrics=['accuracy']
)

# %%
# from tensorflow.keras.preprocessing.image import ImageDataGenerator

# train_datagen = ImageDataGenerator(rescale = 1./255,
#                                    shear_range = 0.2,
#                                    zoom_range = 0.2,
#                                    horizontal_flip = True)

# test_datagen = ImageDataGenerator(rescale = 1./255)

# training_set = train_datagen.flow_from_directory('Data',
#                                                  target_size = (224, 224),
#                                                  batch_size = 32,
#                                                  class_mode = 'categorical')

# test_set = test_datagen.flow_from_directory('Datasets/Test',
#                                             target_size = (224, 224),
#                                             batch_size = 32,
#                                             class_mode = 'categorical')

# %%
import os
import cv2

# %%
os.getcwd()
# Out:
# 'F:\\Data Set\\Transfer learning\\Transfer-Learning-krish naik'

# %%
TRAin_DATA_FOLDER="data"
train="data"

# %%
classes=[]
classes_top=[]
images=[]
missing=0

for class_name in os.listdir(train):
    classes_top.append(class_name)
    class_folder_path=os.path.join(train,class_name)
    classes_label=class_name
    for image_path in glob(os.path.join(class_folder_path,"*.jpg")):
        img_bgr = cv2.imread(image_path, cv2.IMREAD_COLOR)
        imagepath.append(img_bgr)
        if img_bgr is None:
            missing+=1
            continue
        image.append(img_bgr)
        classes.append(classes_label)

# %%
classes_top# because we put on top
# Out:
# ['cats', 'dogs', 'horses', 'Humans']

# %%
classes
# Out:
# ['cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
#  'cats',
# ...

# %%
def resize_images(img):
    img = np.array(img).astype(np.uint8)
  #print(img.dtype)
    res = cv2.resize(img,(256,256), interpolation = cv2.INTER_CUBIC)
    res=res/255.0
    return res

# %%
images = [resize_images(img) for img in image]

# %%
images[0].shape

# %%
plt.imshow(images[0])
plt.colorbar()

# %%
iiimg=np.array(images)

# %%
iiimg.shape

# %%
classes
# Out:
# ['cats', 'dogs', 'horses', 'Humans']

# %%
from sklearn.preprocessing import LabelBinarizer
enc = LabelBinarizer()
y = enc.fit_transform(classes)

# %%
from sklearn.utils import shuffle
x,y = shuffle(iiimg,y, random_state=2)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-9-04d1bd727b3f> in <module>
#       1 from sklearn.utils import shuffle
# ----> 2 x,y = shuffle(iiimg,y, random_state=2)
#
# NameError: name 'iiimg' is not defined

# %%
from sklearn.model_selection import train_test_split

# %%
xtrain,xtest,ytrain,ytest=train_test_split(iiimg,y,test_size=0.3,random_state=20)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-140-369e38f657cb> in <module>
# ----> 1 xtrain,xtest,ytrain,ytest=train_test_split(iiimg,y,test_size=0.3,random_state=20)
#
# ~\Anaconda3\lib\site-packages\sklearn\model_selection\_split.py in train_test_split(*arrays, **options)
#    2116         raise TypeError("Invalid parameters passed: %s" % str(options))
#    2117
# -> 2118     arrays = indexable(*arrays)
#    2119
#    2120     n_samples = _num_samples(arrays[0])
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in indexable(*iterables)
#     246     """
#     247     result = [_make_indexable(X) for X in iterables]
# --> 248     check_consistent_length(*result)
#     249     return result
#     250
#
# ~\Anaconda3\lib\site-packages\sklearn\utils\validation.py in check_consistent_length(*arrays)
#     210     if len(uniques) > 1:
# ...

# %%
history = model.fit(x_train, y_train,
          batch_size=20,
          epochs=10,
          validation_data=(x_test, y_test),
          shuffle=True)

# %%
epochs=range(1,epochs+1)

plt.plot(epochs,history.history['accuracy'])
plt.plot(epochs,history.history['val_accuracy'])
plt.title("Model_accuracy")
plt.xlabels('accuracy')
plt.ylabels('epochs')
plt.legand(['train','val'])

plt.plot(epochs,history.history['loss'])
plt.plot(epochs,history.history['val_loss])
plt.title("Model_loss")
plt.xlabels('loss')
plt.ylabels('epochs')
plt.legand(['train','val'])
